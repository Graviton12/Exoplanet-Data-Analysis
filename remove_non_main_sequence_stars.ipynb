# %% [markdown]
# ### Using Our Filtered Exoplanet Dataset with Removed Outliers and Populated Columns (Samia's Code + Inara's Code + Ari's Manual Column Population)

# %%
# importing
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
import warnings
warnings.filterwarnings('ignore')

# %%
# loading dataset
new_filtered_dataset = pd.read_excel('Exoplanet_filtered_dataset_removed_outliers_complete.xlsx', sheet_name='Data')

# %%
new_filtered_dataset
# Out:
#                  planet_name        host_star_name spectral_type  \
# 0                     K2-7 b                  K2-7           G2V
# 1                 HD 56414 b              HD 56414             A
# 2                  KELT-17 b               KELT-17             A
# 3              KIC 7917485 b           KIC 7917485             A
# 4                HD 102956 b             HD 102956            A
# ...                      ...                   ...           ...
# 5625              KOI-3680 b              KOI-3680           NaN
# 5626             KOI-4777.01              KOI-4777           NaN
# 5627     MOA-2019-BLG-008L b     MOA-2019-BLG-008L           NaN
# 5628  OGLE-2006-BLG-284L A b  OGLE-2006-BLG-284L A           NaN
# 5629              TOI-3819 b              TOI-3819           NaN
#
#       stellar_effective_temp_k planet_equil_temp_k  orbital_period_day  \
# 0                      5743.50                 651           28.682907
# 1                      8500.00                1133           29.049920
# 2                      7454.00                2087            3.080175
# 3                      7067.00                 NaN          840.000000
# 4                      5011.00                 NaN            6.494833
# ...                        ...                 ...                 ...
# 5625                   5818.46                 345          141.241634
# 5626                   3446.00               854.5            0.741600
# 5627                       NaN                 NaN                 NaN
# 5628                       NaN                 NaN                 NaN
# 5629                   5859.00                1633            3.244314
#
#       orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# 0                     0.183900              3.696667                     NaN
# 1                     0.229000              3.710000                     NaN
# 2                     0.048810             17.094000              416.357300
# 3                          NaN                   NaN             3750.394000
# 4                     0.080567                   NaN              300.873467
# ...                        ...                   ...                     ...
# 5625                  0.530040             10.901400              613.411900
# 5626                  0.010475              0.442500               99.200000
# 5627                       NaN                   NaN             6912.767853
# 5628                  2.170000                   NaN              144.000000
# 5629                  0.046110             13.137000              352.789530
#
#       stellar_rad_solar_rad  stellar_mass_solar_mass  distance_parsec  \
# 0                  1.563333                 1.010000          738.553
# 1                  1.750000                 1.890000          272.217
# 2                  1.650000                 1.640000          226.500
# 3                       NaN                 1.630000         1382.890
# 4                  4.453333                 1.643333          121.890
# ...                     ...                      ...              ...
# 5625               0.990000                 0.998571          921.986
# 5626               0.330000                 0.330000          172.245
# 5627                    NaN                 0.766667         2675.000
# 5628                    NaN                 0.350000         4000.000
# 5629               1.540000                 1.240000          558.141
#
#       Eccentricity  stellar_surf_grav  declination_deg  \
# 0              NaN              3.820        -1.065855
# 1           0.6800                NaN       -68.833340
# 2              NaN              4.220        13.735309
# 3           0.1500              4.000        43.632607
# 4           0.0450              3.410        57.640658
# ...            ...                ...              ...
# 5625        0.0992              4.450        45.309657
# 5626        0.0000              4.912        42.032226
# 5627           NaN                NaN       -29.989731
# 5628           NaN                NaN       -29.136667
# 5629        0.0000              4.160        29.388645
#
#                  discovery_method
# 0                         Transit
# 1                         Transit
# 2                         Transit
# 3     Pulsation Timing Variations
# 4                 Radial Velocity
# ...                           ...
# 5625                      Transit
# 5626                      Transit
# 5627                 Microlensing
# 5628                 Microlensing
# 5629                      Transit
#
# [5630 rows x 16 columns]

# %% [markdown]
# #### Understanding the Dataset now that we have populated the spectral_type column

# %%
# Finding the count of entries in the spectral_type column which contain missing values
total_count = len(new_filtered_dataset['spectral_type'])
non_missing_entries_count = new_filtered_dataset['spectral_type'].count()
missing_entries_count= total_count - non_missing_entries_count

print('The Total number of rows in the column (including missing values) :', total_count)
print('The number of entries in the column that have data is: ', non_missing_entries_count)
print('Number of missing entries: ', missing_entries_count)
# Out:
# The Total number of rows in the column (including missing values) : 5630
# The number of entries in the column that have data is:  5532
# Number of missing entries:  98

# %%
# Finding the entries in the spectral_tyoe column which contain / or -
# r is known as raw string and it treats the backslashes inside the string literally and not as escape characters. Without the r, you'd need to double the backslashes (e.g., \\)
# na=False handles the missing entries
contains_dash_or_slash_df= new_filtered_dataset[new_filtered_dataset['spectral_type'].str.contains(r'[/\-]', na=False)]

# List out the filtered entries
print("Entries that contain '/' or '-':")
print(contains_dash_or_slash_df)

# Get the count of such entries
count = len(contains_dash_or_slash_df)
print(f"Count of entries that contain '/' or '-': {count} entries")
# Out:
# Entries that contain '/' or '-':
#                planet_name      host_star_name    spectral_type  \
# 5     KMT-2018-BLG-0087L b  KMT-2018-BLG-0087L          A0 - M2
# 16             HIP 99770 b           HIP 99770            A5-A6
# 31             HIP 39017 b           HIP 39017            A9/F0
# 45                AB Aur b              AB Aur          B9 - A1
# 49                KELT-9 b              KELT-9          B9.5-A0
# ...                    ...                 ...              ...
# 5333         Kepler-1245 b         Kepler-1245  M6V / M8V / M6V
# 5334         Kepler-1245 c         Kepler-1245  M6V / M8V / M6V
# 5509      CFHTWIR-Oph 98 b    CFHTWIR-Oph 98 A            M9-L1
# 5525       NSVS 14256825 b       NSVS 14256825       sdOB / M V
# 5526           V0391 Peg b           V0391 Peg        Sub-Dwarf
#
#       stellar_effective_temp_k planet_equil_temp_k  orbital_period_day  \
# 5                          NaN                 NaN                 NaN
# 16                 8000.000000                 NaN        1.860000e+04
# 31                         NaN                 NaN        3.100000e+04
# 45                 9770.000000         2000 - 2500                 NaN
# 49                10170.000000                4050        1.481121e+00
# ...                        ...                 ...                 ...
# 5333               5387.444444              1043.6        4.354087e+00
# 5334               5380.000000             1189.25        2.936586e+00
# 5509               2320.000000                1800        8.040000e+06
# 5525              40000.000000                 NaN        3.225000e+03
# 5526              29300.000000                 NaN        1.170000e+03
#
#       orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# 5                      0.76500                   NaN                87.40281
# 16                    16.90000                   NaN              5117.03735
# 31                    22.10000                   NaN              7500.75041
# 45                    93.90000                   NaN              2860.45566
# 49                     0.03462             20.591000               845.42780
# ...                        ...                   ...                     ...
# 5333                   0.04852              1.559429                     NaN
# 5334                   0.03720              1.601000                     NaN
# 5509                 200.00000             20.849000              2479.06157
# 5525                   3.12000                   NaN              4497.29450
# 5526                   1.70000                   NaN              1017.05600
#
#       stellar_rad_solar_rad  stellar_mass_solar_mass  distance_parsec  \
# 5                       NaN                 0.105000        6960.0000
# 16                      NaN                 1.850000          40.0765
# 31                      NaN                 1.520000          66.3217
# 45                      NaN                 2.400000         162.1270
# 49                 2.315000                 2.385000         204.4550
# ...                     ...                      ...              ...
# 5333               0.880000                 0.813333         805.9360
# 5334               0.871667                 0.812000         805.9360
# 5509               0.240000                 0.010000              NaN
# 5525               0.190000                 0.420000         820.8770
# 5526               0.230000                 0.500000        1195.9800
#
#       Eccentricity  stellar_surf_grav  declination_deg  \
# 5              NaN                NaN       -27.832061
# 16            0.25                NaN        36.806605
# 31            0.55                NaN        -4.332601
# 45            0.40                NaN        30.551089
# 49            0.00           4.090000        39.938916
# ...            ...                ...              ...
# 5333          0.00           4.441667        43.260753
# 5334          0.00           4.446000        43.260753
# 5509           NaN           3.850000       -23.981150
# 5525          0.12                NaN         4.632371
# 5526          0.00           5.400000        26.418823
#
#                  discovery_method
# 5                    Microlensing
# 16                        Imaging
# 31                        Imaging
# 45                        Imaging
# 49                        Transit
# ...                           ...
# 5333                      Transit
# 5334                      Transit
# 5509                      Imaging
# 5525    Eclipse Timing Variations
# 5526  Pulsation Timing Variations
#
# [142 rows x 16 columns]
# Count of entries that contain '/' or '-': 142 entries

# %% [markdown]
# #### Loading Dataset After Manually Removing rows where the stellar type contained binary stars, pulsars, eclipsing stars, brown dwrafs, white dwardf, and sub dwarfs. As well as setting one star type for entries with multiple star types

# %%
# loading dataset
new_filtered_dataset2 = pd.read_excel('Exoplanet_filtered_dataset_removed_outliers_complete.xlsx', sheet_name='New Data')

# %%
new_filtered_dataset2
# Out:
#      planet_name host_star_name spectral_type  stellar_effective_temp_k  \
# 0       11 Com b         11 Com        G8 III                  4808.000
# 1       11 UMi b         11 UMi        K4 III                  4276.500
# 2       14 And b         14 And        K0 III                  4850.500
# 3       14 Her b         14 Her          K0 V                  5296.985
# 4     16 Cyg B b       16 Cyg B        G2.5 V                  5728.594
# ...          ...            ...           ...                       ...
# 5589      XO-7 b           XO-7          G0 V                  6250.000
# 5590    YSES 2 b         YSES 2          K1 V                  4749.000
# 5591    YZ Cet b         YZ Cet          M4 V                  3103.500
# 5592    YZ Cet c         YZ Cet          M4 V                  3103.500
# 5593    YZ Cet d         YZ Cet          M4 V                  3103.500
#
#      planet_equil_temp_k  orbital_period_day  orbit_semi_major_axis_au  \
# 0                    NaN          324.620000                  1.226000
# 1                    NaN          516.219985                  1.526667
# 2                    NaN          186.300000                  0.761667
# 3                    NaN         1766.378417                  2.814750
# 4                    NaN          799.375000                  1.662833
# ...                  ...                 ...                       ...
# 5589                1743            2.864139                  0.044210
# 5590                 NaN                 NaN                115.000000
# 5591                 471            1.986177                  0.015837
# 5592                 410            2.290707                  0.016887
# 5593                 357            4.656443                  0.027917
#
#       planet_rad_earth_rad  planet_mass_earth_mass  stellar_rad_solar_rad  \
# 0                      NaN             5505.066163              16.380000
# 1                      NaN             3818.094733              26.935000
# 2                      NaN             1224.550433              11.275000
# 3                      NaN             1642.383591               0.976667
# 4                      NaN              533.514528               1.140000
# ...                    ...                     ...                    ...
# 5589                 15.39              225.341470               1.480000
# 5590                   NaN             2336.038790               1.190000
# 5591                   NaN                0.700000               0.166667
# 5592                   NaN                0.900000               0.166667
# 5593                   NaN                1.146667               0.166667
#
#       stellar_mass_solar_mass  distance_parsec  Eccentricity  \
# 0                    2.463333         93.18460      0.234500
# 1                    2.093333        125.32100      0.080000
# 2                    1.726667         75.43920      0.000000
# 3                    0.927143         17.93230      0.362925
# 4                    1.016000         21.13970      0.676033
# ...                       ...              ...           ...
# 5589                 1.410000        234.14900      0.038000
# 5590                 1.100000        109.40600           NaN
# 5591                 0.133333          3.71207      0.030000
# 5592                 0.133333          3.71207      0.030000
# 5593                 0.133333          3.71207      0.073000
#
#       stellar_surf_grav  declination_deg discovery_method
# 0                 2.380        17.793252  Radial Velocity
# 1                 1.765        71.823943  Radial Velocity
# 2                 2.590        39.235837  Radial Velocity
# 3                 4.420        43.816362  Radial Velocity
# 4                 4.344        50.516824  Radial Velocity
# ...                 ...              ...              ...
# 5589              4.250        85.233321          Transit
# 5590                NaN       -66.434574          Imaging
# 5591              5.170       -16.996243  Radial Velocity
# 5592              5.170       -16.996243  Radial Velocity
# 5593              5.170       -16.996243  Radial Velocity
#
# [5594 rows x 16 columns]

# %%
# Finding the count of entries in the spectral_type column which contain missing values
total_count2 = len(new_filtered_dataset2['spectral_type'])
non_missing_entries_count2 = new_filtered_dataset2['spectral_type'].count()
missing_entries_count2 = total_count2 - non_missing_entries_count2

print('The Total number of rows in the column (including missing values) :', total_count2)
print('The number of entries in the column that have data is: ', non_missing_entries_count2)
print('Number of missing entries: ', missing_entries_count2)
# Out:
# The Total number of rows in the column (including missing values) : 5594
# The number of entries in the column that have data is:  5496
# Number of missing entries:  98

# %% [markdown]
# #### For entries in specteral type which do not have a star type, set them at main sequence (V) as default

# %%
# Identify the entrie of the dataset which no not end with III, IV, and V
no_III_IV_V_data = new_filtered_dataset2[~new_filtered_dataset2['spectral_type'].str.endswith('V', na=False) & ~new_filtered_dataset2['spectral_type'].str.endswith(' V', na=False) & 
                             ~new_filtered_dataset2['spectral_type'].str.endswith('IV', na=False) & ~new_filtered_dataset2['spectral_type'].str.endswith(' IV', na=False) &
                             ~new_filtered_dataset2['spectral_type'].str.endswith('III', na=False) & ~new_filtered_dataset2['spectral_type'].str.endswith(' III', na=False) &
                             new_filtered_dataset2['spectral_type'].notna()]
no_III_IV_V_data.shape
# Out:
# (3589, 16)

# %%
no_III_IV_V_data.head(20)
# Out:
#                      planet_name             host_star_name spectral_type  \
# 9                       24 Sex b                     24 Sex             K
# 10                      24 Sex c                     24 Sex            K1
# 12  2MASS J01033563-5515561 AB b  2MASS J01033563-5515561 A       M5.5/M6
# 14     2MASS J02192210-3925225 b    2MASS J02192210-3925225            M6
# 16     2MASS J03590986+2009361 b    2MASS J03590986+2009361             M
# 17     2MASS J04414489+2301513 b    2MASS J04414489+2301513          M8.5
# 18     2MASS J11550485-7919108 b    2MASS J11550485-7919108             M
# 19     2MASS J12073346-3932539 b    2MASS J12073346-3932539            M8
# 20     2MASS J19383260+4603591 b    2MASS J19383260+4603591             B
# 21     2MASS J21252752-8138278 b    2MASS J21252752-8138278             M
# 30                      51 Peg b                     51 Peg             G
# 32                      55 Cnc c                     55 Cnc             K
# 45                       8 UMi b                      8 UMi            K0
# 48                      AB Aur b                     AB Aur       B9 - A1
# 53                      AU Mic b                     AU Mic            M1
# 54                      AU Mic c                     AU Mic         M1 Ve
# 55                      AU Mic d                     AU Mic         M1 Ve
# 57                  BD+03 2562 b                 BD+03 2562            K7
# 59                  BD+15 2375 b                 BD+15 2375          K4
# 60                  BD+15 2940 b                 BD+15 2940            K0
#
#     stellar_effective_temp_k planet_equil_temp_k  orbital_period_day  \
# 9                   5098.000                 NaN          452.800000
# 10                  5098.000                 NaN          883.000000
# 12                       NaN                 NaN                 NaN
# 14                  3064.000                 800                 NaN
# 16                       NaN                2369                 NaN
# 17                  2936.000                 900                 NaN
# 18                       NaN                2506                 NaN
# 19                  2825.000                1200                 NaN
# 20                 29564.000                 305          411.000000
# 21                       NaN                1616                 NaN
# 30                  5763.920                 NaN            4.230530
# 32                  5248.315                 NaN           44.325675
# 45                  4847.200                 NaN           93.400000
# 48                  9770.000         2000 - 2500                 NaN
# 53                  3690.500               596.5            8.463095
# 54                  3685.750               456.5           18.859087
# 55                  3678.000                 NaN           12.735960
# 57                  4095.000                 NaN          481.900000
# 59                  4649.000                1830          153.220000
# 60                  4796.000                 NaN          137.480000
#
#     orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# 9                   1.333000                   NaN              632.460000
# 10                  2.080000                   NaN              273.320000
# 12                 84.000000                   NaN             4131.790000
# 14                156.000000             16.141000             4417.837000
# 16                572.000000                   NaN             5720.911330
# 17                 15.000000                   NaN             2383.600000
# 18                587.000000                   NaN             6356.568140
# 19                 50.500000                   NaN             1430.075000
# 20                  0.920000                   NaN              597.518920
# 21               7493.000000                   NaN             3813.940880
# 30                  0.052262                   NaN              148.360256
# 32                  0.239278                   NaN               55.535134
# 45                  0.490000                   NaN              446.551150
# 48                 93.900000                   NaN             2860.455660
# 53                  0.064860              4.105000               22.221567
# 54                  0.110250              2.850667               14.900000
# 55                       NaN                   NaN                1.053000
# 57                  1.300000                   NaN             2034.112000
# 59                  0.576000                   NaN              337.217630
# 60                  0.539000                   NaN              352.780000
#
#     stellar_rad_solar_rad  stellar_mass_solar_mass  distance_parsec  \
# 9                4.900000                 1.540000          72.0691
# 10               4.900000                 1.540000          72.0691
# 12                    NaN                 0.190000              NaN
# 14               0.280000                 0.110000              NaN
# 16                    NaN                      NaN         117.4350
# 17                    NaN                 0.020000              NaN
# 18                    NaN                      NaN         100.8620
# 19               0.220000                 0.105000          64.3080
# 20               0.200000                 0.480000         396.3320
# 21                    NaN                      NaN          34.1154
# 30               1.220000                 1.046667          15.4614
# 32               0.956667                 0.922500          12.5855
# 45              10.100000                 1.620000         162.5520
# 48                    NaN                 2.400000         162.1270
# 53               0.758571                 0.515714           9.7221
# 54               0.762000                 0.522000           9.7221
# 55               0.740000                 0.510000           9.7221
# 57              32.350000                 1.140000        1070.6300
# 59               8.950000                 1.080000         768.0450
# 60              14.700000                 1.100000         426.4200
#
#     Eccentricity  stellar_surf_grav  declination_deg  \
# 9       0.090000           3.500000        -0.902400
# 10      0.290000           3.500000        -0.902400
# 12           NaN                NaN       -55.265829
# 14           NaN           4.590000       -39.423077
# 16           NaN                NaN        20.159976
# 17           NaN                NaN        23.030854
# 18           NaN                NaN       -79.319756
# 19           NaN           5.030000       -39.548440
# 20      0.330000           5.510000        46.066408
# 21           NaN                NaN       -81.641489
# 30      0.003440           4.316667        20.769096
# 32      0.102375           4.428333        28.329815
# 45      0.060000           2.570000        74.900938
# 48      0.400000                NaN        30.551089
# 53      0.064539           4.425000       -31.342450
# 54      0.043595           4.436667       -31.342450
# 55      0.003050           4.400000       -31.342450
# 57      0.200000           1.890000         2.760108
# 59      0.001000           2.610000        14.616318
# 60      0.260000           2.800000        15.546751
#
#              discovery_method
# 9             Radial Velocity
# 10            Radial Velocity
# 12                    Imaging
# 14                    Imaging
# 16                    Imaging
# 17                    Imaging
# 18                    Imaging
# 19                    Imaging
# 20  Eclipse Timing Variations
# 21                    Imaging
# 30            Radial Velocity
# 32            Radial Velocity
# 45            Radial Velocity
# 48                    Imaging
# 53                    Transit
# 54                    Transit
# 55  Transit Timing Variations
# 57            Radial Velocity
# 59            Radial Velocity
# 60            Radial Velocity

# %%
# Append 'V' to the end of these entries
new_filtered_dataset2.loc[no_III_IV_V_data.index, 'spectral_type'] = no_III_IV_V_data['spectral_type'] + ' V'

# Verify the changes 
new_filtered_dataset2.head(20)
# Out:
#                      planet_name             host_star_name spectral_type  \
# 0                       11 Com b                     11 Com        G8 III
# 1                       11 UMi b                     11 UMi        K4 III
# 2                       14 And b                     14 And        K0 III
# 3                       14 Her b                     14 Her          K0 V
# 4                     16 Cyg B b                   16 Cyg B        G2.5 V
# 5                       17 Sco b                     17 Sco        K3 III
# 6                       18 Del b                     18 Del        G6 III
# 7        1RXS J160929.1-210524 b      1RXS J160929.1-210524          K7 V
# 8                       24 Boo b                     24 Boo         G3 IV
# 9                       24 Sex b                     24 Sex           K V
# 10                      24 Sex c                     24 Sex          K1 V
# 11                      2M0437 b    2MASS J04372171+2651014           M V
# 12  2MASS J01033563-5515561 AB b  2MASS J01033563-5515561 A     M5.5/M6 V
# 13     2MASS J01225093-2439505 b    2MASS J01225093-2439505        M3.5 V
# 14     2MASS J02192210-3925225 b    2MASS J02192210-3925225          M6 V
# 15            2MASS J0249-0557 c         2MASS J0249-0557 A          M6 V
# 16     2MASS J03590986+2009361 b    2MASS J03590986+2009361           M V
# 17     2MASS J04414489+2301513 b    2MASS J04414489+2301513        M8.5 V
# 18     2MASS J11550485-7919108 b    2MASS J11550485-7919108           M V
# 19     2MASS J12073346-3932539 b    2MASS J12073346-3932539          M8 V
#
#     stellar_effective_temp_k planet_equil_temp_k  orbital_period_day  \
# 0                   4808.000                 NaN          324.620000
# 1                   4276.500                 NaN          516.219985
# 2                   4850.500                 NaN          186.300000
# 3                   5296.985                 NaN         1766.378417
# 4                   5728.594                 NaN          799.375000
# 5                   4157.000                1300          578.380000
# 6                   4979.500                 NaN          988.075000
# 7                   4043.250                1750                 NaN
# 8                   4854.500                 NaN           30.340300
# 9                   5098.000                 NaN          452.800000
# 10                  5098.000                 NaN          883.000000
# 11                  3100.000                1450                 NaN
# 12                       NaN                 NaN                 NaN
# 13                  3419.500                1600                 NaN
# 14                  3064.000                 800                 NaN
# 15                  3300.000                 NaN                 NaN
# 16                       NaN                2369                 NaN
# 17                  2936.000                 900                 NaN
# 18                       NaN                2506                 NaN
# 19                  2825.000                1200                 NaN
#
#     orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# 0                   1.226000                   NaN             5505.066163
# 1                   1.526667                   NaN             3818.094733
# 2                   0.761667                   NaN             1224.550433
# 3                   2.814750                   NaN             1642.383591
# 4                   1.662833                   NaN              533.514528
# 5                   1.450000                   NaN             1373.018720
# 6                   2.538667                   NaN             3109.015380
# 7                 330.000000                18.647             3135.750000
# 8                   0.192000                   NaN              284.933890
# 9                   1.333000                   NaN              632.460000
# 10                  2.080000                   NaN              273.320000
# 11                118.000000                   NaN             1271.313630
# 12                 84.000000                   NaN             4131.790000
# 13                 52.000000                11.209             7786.500000
# 14                156.000000                16.141             4417.837000
# 15               1950.000000                   NaN             3686.809520
# 16                572.000000                   NaN             5720.911330
# 17                 15.000000                   NaN             2383.600000
# 18                587.000000                   NaN             6356.568140
# 19                 50.500000                   NaN             1430.075000
#
#     stellar_rad_solar_rad  stellar_mass_solar_mass  distance_parsec  \
# 0               16.380000                 2.463333          93.1846
# 1               26.935000                 2.093333         125.3210
# 2               11.275000                 1.726667          75.4392
# 3                0.976667                 0.927143          17.9323
# 4                1.140000                 1.016000          21.1397
# 5               25.920000                 1.220000         124.9530
# 6                8.650000                 2.166667          76.2220
# 7                1.330000                 0.792500         139.1350
# 8               11.415000                 1.020000          95.9863
# 9                4.900000                 1.540000          72.0691
# 10               4.900000                 1.540000          72.0691
# 11               0.840000                 0.170000         128.4840
# 12                    NaN                 0.190000              NaN
# 13               0.370000                 0.375000          33.8281
# 14               0.280000                 0.110000              NaN
# 15                    NaN                 0.050000          66.0613
# 16                    NaN                      NaN         117.4350
# 17                    NaN                 0.020000              NaN
# 18                    NaN                      NaN         100.8620
# 19               0.220000                 0.105000          64.3080
#
#     Eccentricity  stellar_surf_grav  declination_deg discovery_method
# 0       0.234500              2.380        17.793252  Radial Velocity
# 1       0.080000              1.765        71.823943  Radial Velocity
# 2       0.000000              2.590        39.235837  Radial Velocity
# 3       0.362925              4.420        43.816362  Radial Velocity
# 4       0.676033              4.344        50.516824  Radial Velocity
# 5       0.060000              1.700       -11.837791  Radial Velocity
# 6       0.052000              2.845        10.839138  Radial Velocity
# 7            NaN              4.000       -21.083140          Imaging
# 8       0.037000              2.350        49.844649  Radial Velocity
# 9       0.090000              3.500        -0.902400  Radial Velocity
# 10      0.290000              3.500        -0.902400  Radial Velocity
# 11           NaN              4.500        26.850300          Imaging
# 12           NaN                NaN       -55.265829          Imaging
# 13           NaN              4.860       -24.664613          Imaging
# 14           NaN              4.590       -39.423077          Imaging
# 15           NaN                NaN        -5.959992          Imaging
# 16           NaN                NaN        20.159976          Imaging
# 17           NaN                NaN        23.030854          Imaging
# 18           NaN                NaN       -79.319756          Imaging
# 19           NaN              5.030       -39.548440          Imaging

# %%
# Saving dataset
#new_filtered_dataset2.to_csv('Final_Exoplanet_FIltered_Dataset_Removed_Outliers.csv', index=False)

# %% [markdown]
# #### Host Star Classification

# %%
# loading dataset
exoplanet_dataset = pd.read_excel('Exoplanet_filtered_dataset_removed_outliers_complete.xlsx', sheet_name='Final New Data')

# %%
exoplanet_dataset.columns
# Out:
# Index(['planet_name', 'host_star_name', 'spectral_type',
#        'stellar_effective_temp_k', 'planet_equil_temp_k', 'orbital_period_day',
#        'orbit_semi_major_axis_au', 'planet_rad_earth_rad',
#        'planet_mass_earth_mass', 'stellar_rad_solar_rad',
#        'stellar_mass_solar_mass', 'distance_parsec', 'Eccentricity',
#        'stellar_surf_grav', 'declination_deg', 'discovery_method'],
#       dtype='object')

# %%
exoplanet_dataset.shape
# Out:
# (5594, 16)

# %%
# Finding the count of entries in the spectral_type column which contain missing values
total_count3 = len(exoplanet_dataset['spectral_type'])
non_missing_entries_count3 = exoplanet_dataset['spectral_type'].count()
missing_entries_count3 = total_count3 - non_missing_entries_count3

print('The Total number of rows in the column (including missing values) :', total_count3)
print('The number of entries in the column that have data is: ', non_missing_entries_count3)
print('Number of missing entries: ', missing_entries_count3)
# Out:
# The Total number of rows in the column (including missing values) : 5594
# The number of entries in the column that have data is:  5496
# Number of missing entries:  98

# %%
# filtering dataset to only contain main sequence star type
# na=False handles the missing values
# dataset['spectral_type'].str.endswith('V', na=False) means: filter the dataset to include any star type that ends with 'V' and creates a boolean Series where True indicates that the Star Type ends with 'V' and False otherwise.
# ~dataset['spectral_type'].str.endswith('IV', na=False) means: filter out any star type that ends with 'IV' and inverts the boolean Series so that True indicates that the Star Type does not end with 'IV' and False indicates that it does.
main_sequence_exoplanet = exoplanet_dataset[exoplanet_dataset['spectral_type'].str.endswith('V', na=False) &
                                            exoplanet_dataset['spectral_type'].str.endswith(' V', na=False) & 
                                            ~exoplanet_dataset['spectral_type'].str.endswith('IV', na=False) & 
                                            ~exoplanet_dataset['spectral_type'].str.endswith(' IV', na=False) &
                                            new_filtered_dataset2['spectral_type'].notna()]
main_sequence_exoplanet.shape
# Out:
# (4681, 16)

# %%
main_sequence_exoplanet.sample(15)
# Out:
#         planet_name host_star_name spectral_type  stellar_effective_temp_k  \
# 1484       K2-195 b         K2-195          G4 V               5725.310000
# 2866   Kepler-174 c     Kepler-174          K3 V               4717.666667
# 2668   Kepler-159 c     Kepler-159          M0 V               4257.363636
# 1936  Kepler-1053 b    Kepler-1053          K4 V               4358.366000
# 2658  Kepler-1581 b    Kepler-1581          G0 V               5974.925000
# 4526   Kepler-937 c     Kepler-937        G0   V               6005.967500
# 4938  OGLE-TR-111 b    OGLE-TR-111          K2 V               4985.250000
# 2589  Kepler-1530 c    Kepler-1530          G7 V               5508.412222
# 5096     TOI-1728 b       TOI-1728          M0 V               3980.000000
# 3917   Kepler-487 d     Kepler-487          G7 V               5570.500000
# 2423  Kepler-1407 b    Kepler-1407          G0 V               5928.300000
# 246       GJ 3293 d        GJ 3293        M2.5 V               3466.000000
# 1937  Kepler-1054 b    Kepler-1054          F8 V               6025.111111
# 637     HD 136352 c      HD 136352          G4 V               5726.000000
# 137      DMPP-3 A b       DMPP-3 A          K0 V               5138.000000
#
#      planet_equil_temp_k  orbital_period_day  orbit_semi_major_axis_au  \
# 1484                 720           15.853477                  0.120800
# 2866               352.4           44.000426                  0.206950
# 2668                 285           43.592538                  0.200173
# 1936               835.4            2.414351                  0.029460
# 2658             1114.75            6.283839                  0.068000
# 4526                 377          153.345937                  0.554275
# 4938              1026.5            4.014782                  0.046907
# 2589                1167            5.323283                  0.060000
# 5096                 767            3.491477                  0.039100
# 3917              1262.6            2.418403                  0.034000
# 2423                 747           20.071054                  0.149480
# 246                  NaN           48.134500                  0.193940
# 1937                1156            4.306543                  0.053800
# 637                679.5           27.588403                  0.170533
# 137                  854            6.673400                  0.066200
#
#       planet_rad_earth_rad  planet_mass_earth_mass  stellar_rad_solar_rad  \
# 1484              3.090000                     NaN               0.958000
# 2866              1.534000                     NaN               0.678333
# 2668              2.812778                     NaN               0.592727
# 1936              0.853429                     NaN               0.603000
# 2658              0.767333                     NaN               1.301250
# 4526              2.431000                     NaN               1.215000
# 4938             11.403000              179.573013               0.855000
# 2589              2.200833                     NaN               1.038889
# 5096              5.050000               26.780000               0.620000
# 3917              2.615833                     NaN               0.888750
# 2423              2.404714                     NaN               1.246000
# 246                    NaN                7.600000               0.400000
# 1937              2.105571                     NaN               1.190000
# 637               2.762000               11.110000               1.035000
# 137                    NaN                2.580000               0.910000
#
#       stellar_mass_solar_mass  distance_parsec  Eccentricity  \
# 1484                 0.976667         315.0140           NaN
# 2866                 0.673000         384.7570      0.000000
# 2668                 0.598889         373.7440      0.000000
# 1936                 0.633333         151.1290      0.000000
# 2658                 1.081429         493.1750      0.000000
# 4526                 1.001429        1571.4600      0.000000
# 4938                 0.820000        1068.3300      0.270000
# 2589                 0.965000         489.8760      0.000000
# 5096                 0.650000          60.7980      0.057000
# 3917                 0.908750         872.3430      0.000000
# 2423                 1.081111        1396.4100      0.000000
# 246                  0.420000          20.1903      0.120000
# 1937                 1.117500        1090.5100      0.000000
# 637                  0.863333          14.6820      0.025667
# 137                  0.870000          45.2300      0.070000
#
#       stellar_surf_grav  declination_deg discovery_method
# 1484           4.476667        -8.509536          Transit
# 2866           4.610909        43.832005          Transit
# 2668           4.687778        40.868734          Transit
# 1936           4.678889        39.127366          Transit
# 2658           4.251429        39.603623          Transit
# 4526           4.288571        46.714616          Transit
# 4938           4.510000       -61.405698          Transit
# 2589           4.387500        48.165153          Transit
# 5096           4.660000        64.797153          Transit
# 3917           4.498750        41.222003          Transit
# 2423           4.286667        41.471553          Transit
# 246                 NaN       -25.171340  Radial Velocity
# 1937           4.371250        44.556360          Transit
# 637            4.386667       -48.318817  Radial Velocity
# 137            4.300000       -72.512665  Radial Velocity

# %%
# filtering dataset to only contain subgiant star type
subgiant_exoplanet = exoplanet_dataset[exoplanet_dataset['spectral_type'].str.endswith('IV', na=False) & 
                                       exoplanet_dataset['spectral_type'].str.endswith(' IV', na=False) &
                                       new_filtered_dataset2['spectral_type'].notna()]
subgiant_exoplanet.shape
# Out:
# (95, 16)

# %%
subgiant_exoplanet.sample(15)
# Out:
#       planet_name host_star_name spectral_type  stellar_effective_temp_k  \
# 898   HD 212771 b      HD 212771         G8 IV               5064.333333
# 661      HD 142 b         HD 142         G1 IV               6173.000000
# 597   HD 124330 b      HD 124330         G4 IV               5873.000000
# 737     HD 1605 c        HD 1605         K1 IV               4836.000000
# 627   HD 134606 c      HD 134606         G6 IV               5576.000000
# 826   HD 190360 b      HD 190360         G6 IV               5554.780000
# 624   HD 134060 b      HD 134060         G3 IV               5966.000000
# 1110    HD 5608 b        HD 5608         K0 IV               4866.750000
# 516   HD 106270 b      HD 106270         G5 IV               5571.333333
# 790   HD 179079 b      HD 179079         G5 IV               5686.666667
# 1176   HD 77338 b       HD 77338         K0 IV               5355.500000
# 803   HD 181433 d      HD 181433         K3 IV               4951.210000
# 1118   HD 60532 c       HD 60532         F6 IV               6170.000000
# 625   HD 134060 c      HD 134060         G3 IV               5966.000000
# 572   HD 114613 b      HD 114613         G4 IV               5685.000000
#
#      planet_equil_temp_k  orbital_period_day  orbit_semi_major_axis_au  \
# 898                  NaN          375.766663                  1.190000
# 661                  NaN          347.608485                  1.026000
# 597                  NaN          270.660000                  0.860000
# 737                  NaN         2130.000000                  3.552000
# 627                  NaN           58.883000                  0.300700
# 826                  150         3015.767109                  4.092500
# 624                  NaN            3.269600                  0.044400
# 1110                 NaN          783.449995                  1.897750
# 516                  NaN         2135.000000                  3.662333
# 790                  NaN           14.477000                  0.121000
# 1176                 NaN            5.736100                  0.060700
# 803                  NaN         3884.153333                  4.297823
# 1118                 NaN          602.050000                  1.590000
# 625                  NaN         1291.564600                  2.392800
# 572                  NaN         3913.500000                  5.250000
#
#       planet_rad_earth_rad  planet_mass_earth_mass  stellar_rad_solar_rad  \
# 898                    NaN              887.794800               4.940000
# 661                    NaN              384.481920               1.470000
# 597                    NaN              238.371310                    NaN
# 737                    NaN             1130.272300               3.645000
# 627                    NaN               11.310000               1.160000
# 826                    NaN              483.451726               1.156000
# 624                    NaN               10.100000                    NaN
# 1110                   NaN              468.719328               5.290000
# 516                    NaN             3361.809785               2.580000
# 790                    NaN               28.342410               1.643333
# 1176                   NaN               17.484900               0.925000
# 803                    NaN              177.469737               0.810000
# 1118                   NaN              789.791650               2.570000
# 625                    NaN               29.290000                    NaN
# 572                    NaN              133.007655               2.140000
#
#       stellar_mass_solar_mass  distance_parsec  Eccentricity  \
# 898                  1.706667         111.1550      0.099000
# 661                  1.207500          26.1853      0.239500
# 597                  1.150000          60.1977      0.340000
# 737                  1.320000          88.8047      0.098500
# 627                  1.050000          26.7909      0.055000
# 826                  0.980000          16.0069      0.346800
# 624                  1.090000          24.0125      0.450000
# 1110                 1.587500          58.1105      0.136500
# 516                  1.380000          93.8080      0.249250
# 790                  1.273333          69.7116      0.094667
# 1176                 1.150000          45.9350      0.090000
# 803                  0.790000          26.8762      0.471753
# 1118                 1.470000          25.9716      0.025000
# 625                  1.090000          24.0125      0.110000
# 572                  1.315000          20.2836      0.354000
#
#       stellar_surf_grav  declination_deg discovery_method
# 898            3.440000       -17.264105  Radial Velocity
# 661            4.400000       -49.075362  Radial Velocity
# 597            4.240000        54.408973  Radial Velocity
# 737            3.400000        30.975061  Radial Velocity
# 627            4.330000       -70.520333  Radial Velocity
# 826            4.336000        29.894541  Radial Velocity
# 624            4.430000       -61.422375  Radial Velocity
# 1110           3.190000        33.950577  Radial Velocity
# 516            3.793333        -9.513564  Radial Velocity
# 790            4.110000        -2.638770  Radial Velocity
# 1176           4.600000       -25.528234  Radial Velocity
# 803            4.423333       -66.467784  Radial Velocity
# 1118           3.815000       -22.295866  Radial Velocity
# 625            4.430000       -61.422375  Radial Velocity
# 572            3.920000       -37.802824  Radial Velocity

# %%
# filtering dataset to only contain redgiant star type
redgiant_exoplanet = exoplanet_dataset[exoplanet_dataset['spectral_type'].str.endswith('III', na=False) & 
                                       exoplanet_dataset['spectral_type'].str.endswith(' III', na=False) &
                                       new_filtered_dataset2['spectral_type'].notna()]
redgiant_exoplanet.shape
# Out:
# (111, 16)

# %%
redgiant_exoplanet.sample(15)
# Out:
#        planet_name host_star_name spectral_type  stellar_effective_temp_k  \
# 63     BD+20 274 b      BD+20 274        K5 III                   4296.00
# 706    HD 154391 b      HD 154391        K1 III                   4909.00
# 887    HD 208527 b      HD 208527        M1 III                   4035.00
# 1116    HD 60292 b       HD 60292        K0 III                   4348.00
# 87       bet UMi b        bet UMi        K4 III                   4126.00
# 1833     kap CrB b        kap CrB        K0 III                   4880.00
# 1006    HD 29399 b       HD 29399        K1 III                   4845.00
# 979     HD 25723 b       HD 25723        K1 III                   4766.00
# 1033    HD 33844 c       HD 33844        K0 III                   4861.00
# 811     HD 18438 b       HD 18438      M2.5 III                   3860.00
# 46        81 Cet b         81 Cet        G5 III                   4759.50
# 1042    HD 36384 b       HD 36384        M0 III                   3940.00
# 1115  HD 59686 A b     HD 59686 A        K2 III                   4658.00
# 1026    HD 33142 b       HD 33142        K0 III                   5016.10
# 651     HD 14067 b       HD 14067        G9 III                   4822.75
#
#      planet_equil_temp_k  orbital_period_day  orbit_semi_major_axis_au  \
# 63                   NaN          578.200000                  1.300000
# 706                  NaN         5163.000000                  7.460000
# 887                  NaN          875.500000                  2.100000
# 1116                 NaN          495.400000                  1.500000
# 87                   NaN          522.300000                  1.400000
# 1833                 NaN         1257.132727                  2.700909
# 1006                 NaN          892.700000                  1.913000
# 979                  NaN          457.010000                  1.490000
# 1033                 NaN          916.000000                  2.240000
# 811                  NaN          803.000000                  2.100000
# 46                   NaN          979.135000                  2.258000
# 1042                 NaN          490.000000                  1.300000
# 1115                 NaN          299.360000                  1.086000
# 1026                 NaN          327.300003                  1.073500
# 651                  NaN         2526.046958                  4.875200
#
#       planet_rad_earth_rad  planet_mass_earth_mass  stellar_rad_solar_rad  \
# 63                     NaN             1334.886000              17.300000
# 706                    NaN             2892.238500               8.560000
# 887                    NaN             3146.400000              51.100000
# 1116                   NaN             2065.895000              27.000000
# 87                     NaN             1938.700000              38.300000
# 1833                   NaN              592.694685               4.837000
# 1006                   NaN              498.990600               4.500000
# 979                    NaN              794.571020              13.760000
# 1033                   NaN              556.202500               5.290000
# 811                    NaN             6674.396550              88.470000
# 46                     NaN             1336.619513              11.105000
# 1042                   NaN             2097.667490              38.400000
# 1115                   NaN             2199.383600              13.200000
# 1026                   NaN              432.650835               4.197500
# 651                    NaN             3987.876706              11.856667
#
#       stellar_mass_solar_mass  distance_parsec  Eccentricity  \
# 63                   0.800000       1322.51000      0.210000
# 706                  2.070000        100.94700      0.200000
# 887                  1.600000        312.20200      0.080000
# 1116                 1.700000        315.21100      0.270000
# 87                   1.400000         38.77472      0.190000
# 1833                 1.607143         30.06510      0.101909
# 1006                 1.170000         44.15180      0.050000
# 979                  2.120000        114.81600      0.040000
# 1033                 1.780000        105.77900      0.130000
# 811                  1.840000        224.14600      0.100000
# 46                   1.743333        101.26000      0.121500
# 1042                 1.140000        209.30900      0.200000
# 1115                 1.900000         89.27210      0.050000
# 1026                 1.547500        121.37500      0.088750
# 651                  2.445000        142.02400      0.651000
#
#       stellar_surf_grav  declination_deg discovery_method
# 63               1.9900        21.005269  Radial Velocity
# 706              2.8900        60.648923  Radial Velocity
# 887              1.4000        21.239922  Radial Velocity
# 1116             1.9000        66.235052  Radial Velocity
# 87               1.5000        74.155548  Radial Velocity
# 1833             3.3500        35.655882  Radial Velocity
# 1006             3.2500       -62.823758  Radial Velocity
# 979              2.5000       -12.792224  Radial Velocity
# 1033             3.2400       -14.950978  Radial Velocity
# 811              0.9000        79.418580  Radial Velocity
# 46               2.3800        -3.396361  Radial Velocity
# 1042             1.1000        75.043988  Radial Velocity
# 1115             2.4900        17.085719  Radial Velocity
# 1026             3.4425       -13.986337  Radial Velocity
# 651              2.6100        23.767655  Radial Velocity
