# %% [markdown]
# # Host Star Classifications and Graphs

# %%
# Importing
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading dataset
dataset = pd.read_csv('filtered_exoplanet_dataset_removed_outliers.csv')

# %%
dataset.columns
# Out:
# Index(['planet_name', 'host_star_name', 'orbital_period_day',
#        'orbit_semi_major_axis_au', 'planet_rad_earth_rad',
#        'planet_rad_jup_rad', 'planet_mass_earth_mass', 'planet_mass_jup_mass',
#        'Eccentricity', 'planet_equil_temp_k', 'spectral_type',
#        'stellar_effective_temp_k', 'stellar_rad_solar_rad',
#        'stellar_mass_solar_mass', 'distance_parsec', 'stellar_surf_grav',
#        'declination_deg', 'discovery_method'],
#       dtype='object')

# %%
# deleting uneeded columns
del dataset['planet_rad_earth_rad']
del dataset['planet_rad_jup_rad']
del dataset['planet_mass_earth_mass']
del dataset['planet_mass_jup_mass']
del dataset['Eccentricity']
del dataset['planet_equil_temp_k']
del dataset['declination_deg']
del dataset['discovery_method']

# %%
dataset.head(10)
# Out:
#                planet_name         host_star_name  orbital_period_day  \
# 0                 11 Com b                 11 Com          324.620000
# 1                 11 UMi b                 11 UMi          516.219985
# 2                 14 And b                 14 And          186.300000
# 3                 14 Her b                 14 Her         1766.378417
# 4               16 Cyg B b               16 Cyg B          799.375000
# 5                 17 Sco b                 17 Sco          578.380000
# 6                 18 Del b                 18 Del          988.075000
# 7  1RXS J160929.1-210524 b  1RXS J160929.1-210524                 NaN
# 8                 24 Boo b                 24 Boo           30.340300
# 9                 24 Sex b                 24 Sex          452.800000
#
#    orbit_semi_major_axis_au spectral_type  stellar_effective_temp_k  \
# 0                  1.226000        G8 III                  4808.000
# 1                  1.526667        K4 III                  4276.500
# 2                  0.761667        K0 III                  4850.500
# 3                  2.814750          K0 V                  5296.985
# 4                  1.662833        G2.5 V                  5728.594
# 5                  1.450000        K3 III                  4157.000
# 6                  2.538667        G6 III                  4979.500
# 7                330.000000          K7 V                  4043.250
# 8                  0.192000         G3 IV                  4854.500
# 9                  1.333000           NaN                  5098.000
#
#    stellar_rad_solar_rad  stellar_mass_solar_mass  distance_parsec  \
# 0              16.380000                 2.463333          93.1846
# 1              26.935000                 2.093333         125.3210
# 2              11.275000                 1.726667          75.4392
# 3               0.976667                 0.927143          17.9323
# 4               1.140000                 1.016000          21.1397
# 5              25.920000                 1.220000         124.9530
# 6               8.650000                 2.166667          76.2220
# 7               1.330000                 0.792500         139.1350
# 8              11.415000                 1.020000          95.9863
# 9               4.900000                 1.540000          72.0691
#
#    stellar_surf_grav
# 0              2.380
# 1              1.765
# 2              2.590
# 3              4.420
# 4              4.344
# 5              1.700
# 6              2.845
# 7              4.000
# 8              2.350
# 9              3.500

# %%
dataset.shape
# Out:
# (5630, 10)

# %%
# filtering dataset to only contain main sequence star type
# na=False handles the missing values
# dataset['spectral_type'].str.endswith('V', na=False) means: filter the dataset to include any star type that ends with 'V' and creates a boolean Series where True indicates that the Star Type ends with 'V' and False otherwise.
# ~dataset['spectral_type'].str.endswith('IV', na=False) means: filter out any star type that ends with 'IV' and inverts the boolean Series so that True indicates that the Star Type does not end with 'IV' and False indicates that it does.
filtered_dataset = dataset[dataset['spectral_type'].str.endswith('V', na=False) & ~dataset['spectral_type'].str.endswith('IV', na=False)]

# %%
filtered_dataset.head(10)
# Out:
#                   planet_name           host_star_name  orbital_period_day  \
# 3                    14 Her b                   14 Her         1766.378417
# 4                  16 Cyg B b                 16 Cyg B          799.375000
# 7     1RXS J160929.1-210524 b    1RXS J160929.1-210524                 NaN
# 11                   2M0437 b  2MASS J04372171+2651014                 NaN
# 13  2MASS J01225093-2439505 b  2MASS J01225093-2439505                 NaN
# 15         2MASS J0249-0557 c       2MASS J0249-0557 A                 NaN
# 23  2MASS J22362452+4751425 b  2MASS J22362452+4751425                 NaN
# 24                 30 Ari B b                 30 Ari B          338.533337
# 27                   47 UMa b                   47 UMa         1083.040000
# 28                   47 UMa c                   47 UMa         4088.000000
#
#     orbit_semi_major_axis_au spectral_type  stellar_effective_temp_k  \
# 3                   2.814750          K0 V               5296.985000
# 4                   1.662833        G2.5 V               5728.594000
# 7                 330.000000          K7 V               4043.250000
# 11                118.000000           M V               3100.000000
# 13                 52.000000        M3.5 V               3419.500000
# 15               1950.000000          M6 V                       NaN
# 23                230.000000          K7 V               4045.000000
# 24                  0.998333          F6 V               6315.500000
# 27                  2.095800          G0 V               5861.053333
# 28                  4.911333          G1 V               5850.580000
#
#     stellar_rad_solar_rad  stellar_mass_solar_mass  distance_parsec  \
# 3                0.976667                 0.927143          17.9323
# 4                1.140000                 1.016000          21.1397
# 7                1.330000                 0.792500         139.1350
# 11               0.840000                 0.170000         128.4840
# 13               0.370000                 0.375000          33.8281
# 15                    NaN                 0.050000          66.0613
# 23                    NaN                 0.600000          69.5737
# 24               1.223333                 1.416667          44.6570
# 27               1.175000                 1.043333          13.7967
# 28               1.175000                 1.035000          13.7967
#
#     stellar_surf_grav
# 3               4.420
# 4               4.344
# 7               4.000
# 11              4.500
# 13              4.860
# 15                NaN
# 23                NaN
# 24              4.465
# 27              4.315
# 28              4.315

# %%
filtered_dataset.shape
# Out:
# (1009, 10)

# %%
# saving the output file for a closer look
#filtered_dataset.to_csv('host_star_classification.csv', index=False)
