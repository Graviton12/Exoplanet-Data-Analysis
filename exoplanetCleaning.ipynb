# %% [markdown]
# # **Exoplanet Data Cleaning**

# %%
# Importing
import numpy as np
import pandas as pd

# %%
exoplanets = pd.read_csv("Updated ExoplanetData.csv")

# %%
exoplanets.columns
# Out:
# Index(['planet_name', 'host_star_name', 'num_of_stars', 'num_of_planets',
#        'orbital_period_day', 'orbit_semi_major_axis_au',
#        'planet_rad_earth_rad', 'planet_rad_jup_rad', 'planet_mass_earth_mass',
#        'planet_mass_jup_mass', 'Eccentricity', 'planet_equil_temp_k',
#        'spectral_type', 'stellar_effective_temp_k', 'stellar_rad_solar_rad',
#        'stellar_mass_solar_mass', 'distance_parsec', 'stellar_metallicity',
#        'stellar_metallicity_ratio', 'stellar_surf_grav', 'declination_deg',
#        'discovery_method', 'discovery_year', 'last_update_date',
#        'ref_pub_date', 'solution_type', 'discovery_facility'],
#       dtype='object')

# %%
subset = exoplanets.iloc[:5, :]
subset
# Out:
#   planet_name host_star_name  num_of_stars  num_of_planets  \
# 0    11 Com b         11 Com             2               1
# 1    11 Com b         11 Com             2               1
# 2    11 Com b         11 Com             2               1
# 3    11 UMi b         11 UMi             1               1
# 4    11 UMi b         11 UMi             1               1
#
#    orbital_period_day  orbit_semi_major_axis_au  planet_rad_earth_rad  \
# 0                 NaN                     1.210                   NaN
# 1           326.03000                     1.290                   NaN
# 2           323.21000                     1.178                   NaN
# 3           516.21997                     1.530                   NaN
# 4                 NaN                     1.510                   NaN
#
#    planet_rad_jup_rad  planet_mass_earth_mass  planet_mass_jup_mass  ...  \
# 0                 NaN              5434.70000                17.100  ...
# 1                 NaN              6165.60000                19.400  ...
# 2                 NaN              4914.89849                15.464  ...
# 3                 NaN              4684.81420                14.740  ...
# 4                 NaN              3432.40000                10.800  ...
#
#    stellar_metallicity  stellar_metallicity_ratio stellar_surf_grav  \
# 0                  NaN                        NaN               NaN
# 1                -0.35                     [Fe/H]              2.31
# 2                -0.26                     [Fe/H]              2.45
# 3                -0.02                     [Fe/H]              1.93
# 4                  NaN                        NaN               NaN
#
#    declination_deg  discovery_method  discovery_year  last_update_date  \
# 0        17.793252   Radial Velocity            2007         7/23/2014
# 1        17.793252   Radial Velocity            2007         5/14/2014
# 2        17.793252   Radial Velocity            2007         9/19/2023
# 3        71.823943   Radial Velocity            2009          9/4/2018
# 4        71.823943   Radial Velocity            2009         4/25/2018
#
#    ref_pub_date        solution_type                      discovery_facility
# 0       2011-08  Published Confirmed                        Xinglong Station
# 1       2008-01  Published Confirmed                        Xinglong Station
# 2       2023-08  Published Confirmed                        Xinglong Station
# 3       2017-03  Published Confirmed  Thueringer Landessternwarte Tautenburg
# 4       2011-08  Published Confirmed  Thueringer Landessternwarte Tautenburg
#
# [5 rows x 27 columns]

# %%
exoplanets.shape
# Out:
# (35964, 27)

# %%
exoplanets.describe
# Out:
# <bound method NDFrame.describe of       planet_name host_star_name  num_of_stars  num_of_planets  \
# 0        11 Com b         11 Com             2               1
# 1        11 Com b         11 Com             2               1
# 2        11 Com b         11 Com             2               1
# 3        11 UMi b         11 UMi             1               1
# 4        11 UMi b         11 UMi             1               1
# ...           ...            ...           ...             ...
# 35959   ups And d        ups And             2               3
# 35960   ups Leo b        ups Leo             1               1
# 35961    xi Aql b         xi Aql             1               1
# 35962    xi Aql b         xi Aql             1               1
# 35963    xi Aql b         xi Aql             1               1
#
#        orbital_period_day  orbit_semi_major_axis_au  planet_rad_earth_rad  \
# 0                     NaN                     1.210                   NaN
# 1               326.03000                     1.290                   NaN
# 2               323.21000                     1.178                   NaN
# 3               516.21997                     1.530                   NaN
# 4                     NaN                     1.510                   NaN
# ...                   ...                       ...                   ...
# 35959          1319.00000                     2.570                   NaN
# 35960           385.20000                     1.180                   NaN
# 35961                 NaN                     0.580                   NaN
# 35962           136.75000                     0.680                   NaN
# 35963           136.97000                     0.625                   NaN
#
#        planet_rad_jup_rad  planet_mass_earth_mass  planet_mass_jup_mass  ...  \
# 0                     NaN              5434.70000                17.100  ...
# 1                     NaN              6165.60000                19.400  ...
# 2                     NaN              4914.89849                15.464  ...
# 3                     NaN              4684.81420                14.740  ...
# 4                     NaN              3432.40000                10.800  ...
# ...                   ...                     ...                   ...  ...
# 35959                 NaN              1255.38000                 3.950  ...
# 35960                 NaN               162.09249                 0.510  ...
# 35961                 NaN               642.00000                 2.020  ...
# 35962                 NaN               890.00000                 2.800  ...
# 35963                 NaN               616.90494                 1.941  ...
#
#        stellar_metallicity  stellar_metallicity_ratio stellar_surf_grav  \
# 0                      NaN                        NaN               NaN
# 1                   -0.350                     [Fe/H]              2.31
# 2                   -0.260                     [Fe/H]              2.45
# 3                   -0.020                     [Fe/H]              1.93
# 4                      NaN                        NaN               NaN
# ...                    ...                        ...               ...
# 35959                  NaN                        NaN               NaN
# 35960               -0.200                     [Fe/H]              2.46
# 35961                  NaN                        NaN               NaN
# 35962               -0.205                     [Fe/H]              2.66
# 35963               -0.110                     [Fe/H]              2.61
#
#        declination_deg  discovery_method  discovery_year  last_update_date  \
# 0            17.793252   Radial Velocity            2007         7/23/2014
# 1            17.793252   Radial Velocity            2007         5/14/2014
# 2            17.793252   Radial Velocity            2007         9/19/2023
# 3            71.823943   Radial Velocity            2009          9/4/2018
# 4            71.823943   Radial Velocity            2009         4/25/2018
# ...                ...               ...             ...               ...
# 35959        41.403815   Radial Velocity            1999         8/21/2014
# 35960        -0.823564   Radial Velocity            2021         1/10/2022
# 35961         8.461105   Radial Velocity            2007         7/23/2014
# 35962         8.461105   Radial Velocity            2007         5/14/2014
# 35963         8.461105   Radial Velocity            2007         9/19/2023
#
#        ref_pub_date        solution_type  \
# 0           2011-08  Published Confirmed
# 1           2008-01  Published Confirmed
# 2           2023-08  Published Confirmed
# 3           2017-03  Published Confirmed
# 4           2011-08  Published Confirmed
# ...             ...                  ...
# 35959       2004-01  Published Confirmed
# 35960       2021-12  Published Confirmed
# 35961       2011-08  Published Confirmed
# 35962       2008-06  Published Confirmed
# 35963       2023-08  Published Confirmed
#
#                            discovery_facility
# 0                            Xinglong Station
# 1                            Xinglong Station
# 2                            Xinglong Station
# 3      Thueringer Landessternwarte Tautenburg
# 4      Thueringer Landessternwarte Tautenburg
# ...                                       ...
# 35959                  Multiple Observatories
# 35960       Okayama Astrophysical Observatory
# 35961       Okayama Astrophysical Observatory
# 35962       Okayama Astrophysical Observatory
# 35963       Okayama Astrophysical Observatory
#
# [35964 rows x 27 columns]>

# %%
exoplanets_copy = exoplanets.copy()

def flag_outliers_zscore(series, threshold=3):
    mean = series.mean()
    std_dev = series.std()
    
    # Check if standard deviation is lower than the threshold
    if std_dev <= 0.5:
        return pd.Series([False] * len(series), index=series.index)
    
    z_scores = (series - mean) / std_dev
    return abs(z_scores) > threshold

# Function to flag outliers for a specific column using z-score method within each group
def flag_outliers_for_column_zscore(df, column_name, threshold=3):
    # Group the DataFrame by the "planet_name" column
    grouped = df.groupby("planet_name")
    
    # Apply the outlier detection function to each group
    for group_name, group_data in grouped:
        outlier_flags = flag_outliers_zscore(group_data[column_name], threshold)
        # Update the corresponding rows in the original DataFrame with outlier flags
        df.loc[group_data.index, column_name + '_outlier'] = outlier_flags

# Get numerical columns in the DataFrame
numerical_columns = exoplanets_copy.select_dtypes(include=[np.number]).columns

# Apply the outlier detection using z-score method within each group for each numerical column
for column_name in numerical_columns:
    flag_outliers_for_column_zscore(exoplanets_copy, column_name)

# Display the DataFrame with outlier flags
print(exoplanets_copy)
# Out:
#       planet_name host_star_name  num_of_stars  num_of_planets  \
# 0        11 Com b         11 Com             2               1
# 1        11 Com b         11 Com             2               1
# 2        11 Com b         11 Com             2               1
# 3        11 UMi b         11 UMi             1               1
# 4        11 UMi b         11 UMi             1               1
# ...           ...            ...           ...             ...
# 35959   ups And d        ups And             2               3
# 35960   ups Leo b        ups Leo             1               1
# 35961    xi Aql b         xi Aql             1               1
# 35962    xi Aql b         xi Aql             1               1
# 35963    xi Aql b         xi Aql             1               1
#
#        orbital_period_day  orbit_semi_major_axis_au  planet_rad_earth_rad  \
# 0                     NaN                     1.210                   NaN
# 1               326.03000                     1.290                   NaN
# 2               323.21000                     1.178                   NaN
# 3               516.21997                     1.530                   NaN
# 4                     NaN                     1.510                   NaN
# ...                   ...                       ...                   ...
# 35959          1319.00000                     2.570                   NaN
# 35960           385.20000                     1.180                   NaN
# 35961                 NaN                     0.580                   NaN
# 35962           136.75000                     0.680                   NaN
# 35963           136.97000                     0.625                   NaN
#
#        planet_rad_jup_rad  planet_mass_earth_mass  planet_mass_jup_mass  ...  \
# 0                     NaN              5434.70000                17.100  ...
# 1                     NaN              6165.60000                19.400  ...
# 2                     NaN              4914.89849                15.464  ...
# 3                     NaN              4684.81420                14.740  ...
# 4                     NaN              3432.40000                10.800  ...
# ...                   ...                     ...                   ...  ...
# 35959                 NaN              1255.38000                 3.950  ...
# 35960                 NaN               162.09249                 0.510  ...
# 35961                 NaN               642.00000                 2.020  ...
# 35962                 NaN               890.00000                 2.800  ...
# 35963                 NaN               616.90494                 1.941  ...
#
#        Eccentricity_outlier  planet_equil_temp_k_outlier  \
# 0                     False                        False
# 1                     False                        False
# 2                     False                        False
# 3                     False                        False
# 4                     False                        False
# ...                     ...                          ...
# 35959                 False                        False
# 35960                 False                        False
# 35961                 False                        False
# 35962                 False                        False
# 35963                 False                        False
#
#       stellar_effective_temp_k_outlier  stellar_rad_solar_rad_outlier  \
# 0                                False                          False
# 1                                False                          False
# 2                                False                          False
# 3                                False                          False
# 4                                False                          False
# ...                                ...                            ...
# 35959                            False                          False
# 35960                            False                          False
# 35961                            False                          False
# 35962                            False                          False
# 35963                            False                          False
#
#        stellar_mass_solar_mass_outlier  distance_parsec_outlier  \
# 0                                False                    False
# 1                                False                    False
# 2                                False                    False
# 3                                False                    False
# 4                                False                    False
# ...                                ...                      ...
# 35959                            False                    False
# 35960                            False                    False
# 35961                            False                    False
# 35962                            False                    False
# 35963                            False                    False
#
#        stellar_metallicity_outlier  stellar_surf_grav_outlier  \
# 0                            False                      False
# 1                            False                      False
# 2                            False                      False
# 3                            False                      False
# 4                            False                      False
# ...                            ...                        ...
# 35959                        False                      False
# 35960                        False                      False
# 35961                        False                      False
# 35962                        False                      False
# 35963                        False                      False
#
#       declination_deg_outlier  discovery_year_outlier
# 0                       False                   False
# 1                       False                   False
# 2                       False                   False
# 3                       False                   False
# 4                       False                   False
# ...                       ...                     ...
# 35959                   False                   False
# 35960                   False                   False
# 35961                   False                   False
# 35962                   False                   False
# 35963                   False                   False
#
# [35964 rows x 45 columns]

# %%
exoplanets_copy.to_csv('cleaned_exoplanets_z_score.csv', index=False)
